# %%
from skimage.io import imread
from matplotlib import pyplot as plt
import cv2

# %matplotlib inline

# %%
img = cv2.imread('./живая-утка-и-утиное-лицо-3.jpg', 0)
plt.hist(img.ravel(),256,[0,256]); 
plt.show()
plt.imshow(img)
plt.show()
