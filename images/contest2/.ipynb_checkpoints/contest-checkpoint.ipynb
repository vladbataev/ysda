# %%
from skimage.transform import resize
from skimage.io import imread
from skimage.draw import circle
import numpy as np
from matplotlib import pyplot as plt
import keras
import glob
import os
import pandas as pd

TRAIN_DATA_FOLDER = "./data/facial-keypoints-train/"
TEST_DATA_FOLDER = "./data/facial-keypoints-test/"
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
train_pictures_filenames = sorted(glob.glob(os.path.join(TRAIN_DATA_FOLDER, "images/*.jpg")))
keypoints_df = pd.read_csv(os.path.join(TRAIN_DATA_FOLDER, "gt_train.csv"))

# %%
def split_points(array):
    size = len(array)
    points = np.zeros(shape=(size // 2, 2))
    for i in range(size // 2):
        points[i][0] = array[2 * i + 1]
        points[i][1] = array[2 * i]
    return points

# %%
def prepare_image(filename, keypoints_df, new_shape=(170, 170, 3)):
    img = imread(filename)
    img_shape = img.shape

    relative_filename = filename.split('/')[-1]
    img_keypoints = split_points((keypoints_df.loc[keypoints_df["filename"] == relative_filename]).as_matrix()[0][1:])
    
    k_x = float(new_shape[0]) / img_shape[0]
    k_y = float(new_shape[1]) / img_shape[1]

    new_img_keypoints = np.array(list(map(lambda x: (int(x[0] * k_x), int(x[1] * k_y)), img_keypoints)))
    new_img = resize(img, new_shape)
    return new_img, new_img_keypoints

# %%
img, keypoints = prepare_image(train_pictures_filenames[3], keypoints_df)

# %%
img
# Out:
# array([[[ 0.12022105,  0.06744107,  0.06157663],
#         [ 0.24177855,  0.18074048,  0.17395848],
#         [ 0.33610828,  0.27945858,  0.27377366],
#         ...,
#         [ 0.7481152 ,  0.79558925,  0.86470588],
#         [ 0.73987706,  0.78735111,  0.86470588],
#         [ 0.63629188,  0.67734297,  0.74771626]],
#
#        [[ 0.21155872,  0.15052066,  0.14373865],
#         [ 0.34825687,  0.27766863,  0.2698255 ],
#         [ 0.39568627,  0.33017301,  0.32359862],
#         ...,
#         [ 0.8786668 ,  0.92890902,  1.        ],
#         [ 0.87137363,  0.92067019,  1.        ],
#         [ 0.73987706,  0.78130714,  0.86470588]],
#
#        [[ 0.25562182,  0.19458376,  0.18780175],
#         [ 0.40916412,  0.33857589,  0.33073275],
#         [ 0.41893276,  0.3534195 ,  0.3468451 ],
#         ...,
#         [ 0.88512789,  0.92711174,  0.9974252 ],
#         [ 0.8735172 ,  0.91390936,  0.99361897],
#         [ 0.73714431,  0.77005699,  0.85592917]],
#
#        ...,
#        [[ 0.14910442,  0.25003664,  0.30898026],
#         [ 0.16359387,  0.24530158,  0.28550919],
#         [ 0.25312097,  0.28000882,  0.27656218],
#         ...,
#         [ 0.90980392,  0.91764706,  1.        ],
#         [ 0.90980392,  0.91764706,  1.        ],
#         [ 0.7867128 ,  0.79349481,  0.86470588]],
#
#        [[ 0.13191003,  0.25482394,  0.32338205],
#         [ 0.18128869,  0.28521039,  0.33653681],
#         [ 0.2718753 ,  0.3174503 ,  0.32327159],
#         ...,
#         [ 0.90980392,  0.91764706,  1.        ],
#         [ 0.90980392,  0.91764706,  1.        ],
#         [ 0.7867128 ,  0.79349481,  0.86470588]],
#
#        [[ 0.14367881,  0.26389986,  0.32840871],
#         [ 0.2185402 ,  0.32332221,  0.37374842],
#         [ 0.28504376,  0.33790352,  0.34767759],
#         ...,
#         [ 0.7867128 ,  0.79349481,  0.86470588],
#         [ 0.7867128 ,  0.79349481,  0.86470588],
#         [ 0.68027519,  0.68613963,  0.74771626]]])

# %%
for keypoint in keypoints:
    img[circle(keypoint[0], keypoint[1], 3)] = (1, 0, 0)
plt.imshow(img)

# %%
first_img = imread(train_pictures_filenames[0])
shape = first_img.shape
new_shape = (170, 170, 3)
first_img_res = resize(first_img, new_shape)
k_x = float(new_shape[0]) / shape[0]
k_y = float(new_shape[1]) / shape[1]

new_keypoints = map(lambda x: (int(x[0] * k_x), int(x[1] * k_y)), img_keypoints)

for keypoint in new_keypoints:
    first_img_res[circle(keypoint[0], keypoint[1], 3)] = (0, 255, 0)
plt.imshow(first_img_res)
