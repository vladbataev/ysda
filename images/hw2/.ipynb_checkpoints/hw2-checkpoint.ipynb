# %%
# %matplotlib inline
import skimage
from skimage import io
from matplotlib import pyplot as plt
from pylab import rcParams
import numpy as np
rcParams['figure.figsize'] = 10, 10

# %%
img0 = io.imread('Klad00.jpg')
plt.imshow(img0)

# %%
import copy
copy_img0 = copy.deepcopy(img0) 
red, green, blue = copy_img0[..., 0], img0[..., 1], img0[..., 2]
copy_img0[(green > 110) | ((blue < 100) & (red < 50) & (green > 80))] = [0,0,0]

# %%
import copy
#img0 = copy.deepcopy(img0) 
img0[(green > 110) | ((blue < 100) & (red < 50) & (green > 80))] = [0,0,0]

# %%
plt.imshow(img0)

# %%
def binarize(img, threshold):
    return img[:,:,:]
